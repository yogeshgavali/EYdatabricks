-- %%
DESCRIBE CATALOG EXTENDED dev;

-- %%
CREATE CATALOG dev_sql 
COMMENT "This catalog is using SQL"

-- %%
DESCRIBE CATALOG EXTENDED dev_sql;

-- %%
DROP CATALOG dev_sql CASCADE;

-- %%
SHOW CATALOGS

-- %%
%python
spark.catalog.tableExists("samples.accuweather.forecast_daily_calendar_imperial_1")

-- %%
CREATE SCHEMA IF NOT EXISTS dev.bronze;

-- %%
CREATE TABLE IF NOT EXISTS dev.bronze.emp (
  emp_id INT,
  emp_name STRING,
  dept_id STRING,
  SALARY DOUBLE)

-- %%
DESCRIBE EXTENDED dev.bronze.emp;

-- %%
INSERT INTO dev.bronze.emp (emp_id, emp_name, dept_id, salary) VALUES (1001, 'Subhan', 'D101', 10000);
INSERT INTO dev.bronze.emp (emp_id, emp_name, dept_id, salary) VALUES (1002, 'Ramesh', 'D101', 12000);
INSERT INTO dev.bronze.emp (emp_id, emp_name, dept_id, salary) VALUES (1003, 'Suresh', 'D102', 5000);
INSERT INTO dev.bronze.emp (emp_id, emp_name, dept_id, salary) VALUES (1004, 'Rahim', 'D102', 12000);

-- %%
--select * from dev.bronze.emp@v0
--select * from dev.bronze.emp version as of 3
select * from dev.bronze.emp timestamp as of '2025-06-18T17:40:23.000+00:00'

-- %%
DESCRIBE TABLE dev.bronze.emp;

-- %%
DESCRIBE TABLE EXTENDED dev.bronze.emp;

-- %%
DESCRIBE HISTORY dev.bronze.emp;

-- %%
CREATE TEMPORARY VIEW temp_emp
AS
SELECT * FROM dev.bronze.emp
where dept_id='D102'

-- %%
CREATE OR REPLACE VIEW dev.bronze.emp_vw
AS
SELECT * FROM dev.bronze.emp
where dept_id='D101'

-- %%
select * from dev.bronze.emp_vw

-- %%
USE CATALOG dev;
SHOW VIEWS IN dev.bronze;

-- %%
USE CATALOG dev;
USE SCHEMA bronze;
DESCRIBE VIEW emp_vw;
